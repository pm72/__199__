# %% [markdown]
# ყველაზე მარტივ პროგრამა წარმოადგენს ცარიელი ფაილი, რომელსაც აქვს `py` გაფართეოება. `python` ენაზე ჩაწერილ პროგრამას აქვს `py` გაფართოება. მაგ.: `my_first_python_programm.py`

# %% [markdown]
# `'#'` სიმბოლოთო დაწყებული სტრიქონი განიხილება, როგორც კომენტარი და ინტერპრეტატორის მიერ არ განიხილება შემსრულებელ საბრძანებო ინსტრუქციად. იგი მხოლოდ ინფორმაციის ხასიათს ატარებს.

# %%
# ცარიელი პროგრამა

# %% [markdown]
# ახლა ჩვენს პროგრამას ვასწავლოთ გააკეთოს სასარგებლო რამ. მაგალითად დავაბეჭდინოთ ეკრანზე ტექსტი.  `Hello world!..`

# %%
print("Hello, world!..")
# print("დღეს უყურეთ ფილმს 'არმაგედონი'")
# print('დღეს უყურეთ ფილმს "არმაგედონი"')
# print('დღეს უყურეთ ფილმს "არმაგედონი"')
# Out:
# Hello, world!..
# დღეს უყურეთ ფილმს 'არმაგედონი'
# დღეს უყურეთ ფილმს "არმაგედონი"

# %% [markdown]
# შესაძლებელია `print` ასეც ჩავწეროთ:

# %%
print("გამარჯობა", "ნიკა!")

# %% [markdown]
# `print`-ში სიტყვებს შორის ინტერვალი (`space`) ავტომატურად თავსდება.
#
# თუ ის არ გვჭირდება, მაშინ `print` ფუნქციის გამოძახებისას, ბოლოში უნდა დავამატოთ კიდევ ერთი არგუმნეტი `sep`:

# %%
print("2", "+", "2", "=", "4", sep='')

# %% [markdown]
# ახლა შევეცადოთ რამდენიმე სტრიქონინანი ტექსტი გამოვიტანოთ ეკრანზე:

# %%
print("გამარჯობა მაკა!")
print("გამარჯობა ლიკა!")

# %% [markdown]
# როგორც ვხედავთ `print` ფუნქცია ახალი ხაზიდან ბეჭდავს ინფორმაციას (იყენებს `Enter`-ს).
#
# თუ გვინდა რომ რამოდენიმე `print`-ის გამოყენებით ინფორმაცია არ იყოს ახალი ხაზიდან დაბეჭდილი, უნდა გამოვიყენოთ არგუმნეტი `end`:

# %%
print("1", end="")
print("23", end="")
print("456")

# %%
help(print)

# %%
print("Hello", 2.58, "Paata", 17)
print("Hello", 2.58, "Paata", 17, sep='')

print()

print("პაატა მამფორია ", end='')
print("დემეტრე მამფორია")
print(5/89)
# Out:
# Hello 2.58 Paata 17
# Hello2.58Paata17
#
# პაატა მამფორია დემეტრე მამფორია
# 0.056179775280898875

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ### დავალება
#
# 1. იპოვეთ და შეასწორეთ შეცომა პროგრამაში:
#
#     `print("აქცია "კეთილი საქმე".")`
#
#     `print("გამარჯობა", თინა)`
#
# 2. შეავსეთ მრავალწერტილები ისე, რომ პროგრამ დაბეჭდოს `Python`:
#
#     `print("Py", ....)`
#
#     `....`
#
#     `print("on")`
#
# 3. დაწერეთ პროგრამა, რომელიც დაბეჭდავს შოთა რუსთაველის პოემის „ვეფხისტყაოსნის“ ფრაგმენტს:
#
# ```
# ხრმალი გავსტყორცნე, გადვიჭერ
#                              ვეფხი შევიპყარ
#                                           ხელითა...
# ```
#
# 4. დაწერეთ პროგრამა, რომელიც დაბეჭდავს ნახატს:
#
#                   Oooo
#           Oooo   (   )
#          (   )    )  )
#          (  (    (__/
#           \__)

# %%
print("py", end='')
print("th", end='')
print("on")
# Out:
# python

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print(45)
print(54, 10, 78)

print("paata", end='***')
print(48)
# Out:
# 45
# 54 10 78
# paata***48
