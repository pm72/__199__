# %%
# ახარისხება
# print(2**3)
# print(2**3**2)    #  2**9


# a + 78 = b*b - 4ac     =>  a = b*b - 4ac - 78

# ოპერაციები ერთ ცვლადზე 
# i = 70
# i = i + 1

# print(i)

# x = -10

# მრავალმხრივი მინიჭება  (კასკადური მინიჭება)
a = 90
b = 87

a, b = 5, 8
x, y = a + b - 7, "Hello" + " " + "Python"
print("x =", x)
print("y =", y)

a, b = 0, 5
b = b ** a
print(b)
# Out:
# x = 6
# y = Hello Python
# 1

# %% [markdown]
# ### არითმეტიკული გამოსახულება
#
# * მიმატება +
# * გამოკლება -
# * გამრავლება *
# * გაყოფა /
# * მთელზე გაყოფა //
# * ნაშთის აღება %
# * ახარისხება **
#
# თავიდან განვიხილოთ ოპერაციები ერთ ცვლადზე. მინიჭების ოპერაცია:
# `i = i + 1`
# `i` ცვლადს უმატებს `1`-ს. ეს ოპერაცია ხშირად გამოიყენება. მაგ.: ციკლისას.
#
# მინიჭება უფრო რთული გამოსახულებისას:
#
# \begin{equation}
# a = \frac{c + b - 1}{d} \cdot 2
# \end{equation}
#
# ჩაიწერება ასე:
# `a = (c + b - 1) / d * 2`
# `a = (c + b - 1) * 2 / d`
#
# ასეთ ჩანაწერს არითმეტიკული გამოსახულების _წრფივ ჩანაწერს_ უწოდებენ (ერთ ხაზზე ჩაწერა). გრძელი ფორმულის ჩაწერისას შესაძლებელი ფორმულა გავყოთ მაგალითად ორ ნაწილად (ორ ხაზზე ჩავწეროთ):
#
# ```python
# a = x * (2*c + 4*b - 8*f) + 2 * a * c
# a = x * (2*c + 4*b - 8*f) \
# + 2 * a * c
# ```
#
# ფრჩხილების შიგნით გადატანისას `\` სიმბოლო საჭორო არ არის:
#
# ```python
# a = (c + 5 + 2 * c)
# a = (c + 5
# + 2 * c)
# ```
#
# გამოსახულებაში არითმეტიკული ოპერაციების მოქმედება ხორციელდება _პრიორიტეტული_ ოპერაციით:
# * ფრჩხილებში მოთავსებული ოპერაციები სრულდება პირველად
# * შემდეგი პრიორიტეტი აქვს ახარისხებას, მარჯვნიდან მარცხნივ: `2**3**2 <===> 2**(3**2)`
# * შემდეგია გამრავლება და გაყოფა, მარცხნიდან მარჯვნივ
# * ბოლოს შეკრება-გოკლება, მარცხნიდან მარჯვნივ
#
# ამრიგად, გამრავლებას და გაყოფას აქვს ერთნაირი პრიორიტეტი, უფრო მაღალი, ვიდრე შეკრება-გამოკლებას.
#
# მაგალითად, გამოსახულებაში
# `a = (c + b - 1) / 2 * d`
# პირველად შესრულდება ფრჩხილებში მოთავსებული ოპერაცია: მიმატება და შემდეგ გამოკლება; შემდეგ გაყოფა 2-ზე და ბოლოს -- გამრავლება `d`-ზე.
#
# `Python`-ში შესალებელია _მრავალმხრივი_ მინიჭება:
#     `a, b = 1, 2 `
# იგივეა, რაც
#     `a = 1`
#     `b = 2`
# ითვლება, რომ ეს ორი მოქმედება ხორციელდება პარალელურად, ერთდროულად.
#
# გამოსახულება `a = b = 0` ნიშნავს:
# ```python
# b = 0
# a = 0
# ```
#
# ცვლადის მნიშვნელობის შესაცვლელად, მოსახერხებელია _შემოკლებული_ ჩანაწერის გამოყენება:
#
# ```python
# სრული ჩანაწერი       შემოკლებული ჩანაწერი
# a = a + b             a += b
# a = a - b             a -= b
# a = a * b             a *= b
# a = a / b             a /= b
# ```
#
# თუ არითმეტიკულ გამოსახულებაში მონაწილეობენ სხვადასხვა ტიპის ცვლადები (მთელი, ათწილადი) შედეგი იქნება ათწილადი: ხდება ავტომატური გარდაქმნა _პატარიდან დიდისკენ_. პირიქით გარდაქმნა ავტომატურად არ ხდება: პროგრამისტმა უნდა გარდაქმნას, თუმცა შესაძლებელია ინფორმაციის დაკარგვა.
#
# გაყოფის შედეგი ყოველთვის არის ათწილადი, მიუხედავად მთელი ტიპის ოპერანდებისა.

# %%
5 + 7.0
# Out:
# 12.0

# %% [markdown]
# ### მთელზე გაყოფა

# %%
print(5/2)
print(8/2)
print(2/3)
print(19 / 5)
print(19 // 5)
print(19 % 5)
print(16 % 5)
# Out:
# 2.5
# 4.0
# 0.6666666666666666
# 3.8
# 3
# 4
# 1

# %%
num1 = 89
print(num1 % 10, num1 // 10, sep='')

num1 = 487
print(num1 % 10, num1 // 10 % 10, num1 // 100, sep=' *** ', end='; ')
print("Paata")
print("Mamporia")

print()

num1 = 4871
print(num1 % 10, num1 // 10 % 10, num1 // 100 % 10, num1 // 1000, sep='')   # 1748

print()

seconds = 14500
print(seconds // 60, seconds % 60, sep=':')
print(seconds // 3600, seconds // 60 % 60, seconds % 60, sep=':')
print(4*3600 + 1*60 + 40)
# Out:
# 98
# 7 *** 8 *** 4; Paata
# Mamporia
#
# 1784
#
# 241:40
# 4:1:40
# 14500

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# გაყოფისას მიღებული შედეგი არ არის მთელი, ასეთ რიცხვებს უწოდებენ _ნამდვილი რიცხვები_, ათწილადი რიცხვები. პროგრამირებაში მათ _მცოცავწერტილიანი რიცხვები_ ჰქვია (`floating point`).
#
# ხშირად საჭიროა გაყოფისას მივიღოთ მთელი რიცხვი, ან ნაშთი. მაგალითად, ცნობილია დროის ინტერვალი წამებში, ვთქვათ 289 წამი, და გვინდა განვსაზღვროთ რამდენი წუთისა და წამისგან შედგება 289 წამი (289 წამი = 4 წთ. 49 წმ.). აქ 4 არის მთელი რიცხვი 289:60, 49 კი -- ნაშთი ამ გაყოფიდან.
#
# ასეთ შემთხვევაში გამოიყენება სპეციალური ოპერატორები:
#
# // -- მთელზე გაყოფა (ნაშთის უგულვებელყოფა)
#
# % -- ნაშთის აღება გაყოფისას
#
# ```python
# time_sec = 289
# minutes = time_sec // 60    # = 4
# seconds = time_sec % 60     # = 49
# ```
#
# ამ ოპერაციების გამოყენებით მოსახერხებელია მუშაობა ცალკეულ ციფრებზე. ნებისმიერი მთელი რიცხვის 10-ზე გატოფისას მიღებული ნათში წარმოადგენს რიცხვის ბოლო ციფრს.
# ```python
# N = 123
# last_digit = N % 10    # = 3
# ```
#
# თუ რიცხვს გავყობთ 10-ზე და ავიღებთ მხოლოდ მთელ ნაწილს, ჩვენ _„გადავაგდებთ“_ ბოლო ციფრს:
# ```python
# N = 123
# digits2 = N // 10    # = 12
# ```
#
# საინტერესო შედეგს გვაძლევს `'//'` და `'%'` ოპერაცია უარყოფითი რიცხვების დროს:
# ```python
# print(-7 // 2)     # = -4
# print(-7 // 2)     # = 1
# ```
#
# საქმე იმაშია, რომ ნაშთი ყოველთვის დადებითია. გაყოფისას ჩვენ ვეძებთ -7-ზე ყველაზე ახლოს მყოფ ნაკლებ უარყოფით რიცხვს, რომელიც უნაშთოთ იყოფა 2-ზე, ასეთი რიცხვის -8. ამიტომ `-7 // 2 = -4` და ნაშთი კი -- `-7 = -8 + 1`.
#
# `python` ენაზე (განსხვავებით სხვა ენებისგან `C++, pascal, java ...`) ეს ოპერაციები მათემატიკურად სწორად სრულდება.

# %% [markdown]
# ### მონაცემების ეკრანზე გამოტანა
#
# თქვენ უკვე იცით, რომ ფუნქცია `print()` გუმენტებს შორის _ინტერვალებს_ ბეჭდავს:
# ```python
# a = 12
# b = 5
# c = 155
# print(a, b, c)      # 12 5 155
# ```
# მაგრამ ჩვენ გვინდა ეს მონაცემები მოწესრიგებულად გამოვიტანოთ, მაგ.: ცხრილის სახით:
# ```python
#   12    5 155
#   211 315   8
# ```
# დავუშვათ, ვმუშაობთ ნატურალურ რიცხვებთან, რომლებიც 1000-ზე ნაკლებია. ყოველი რიცხვისთვის უნდა გამოვყოთ, ვთქვათ, ოთხი პოზიცია ეკრანზე: სამი რიცხვის ჩასაწერად და ერთი ინტერვალისთვის, რათა განვასვაოთ რიცხვები ერთმანეთისგან:
# ```python
# print(f"{a:4}{b:4}{c:4}")
# ```
# ასეთ ჩანაწერს _ფორმატირებული გამოტანა_ ეწოდება.

# %% [markdown]
# ### დავალება
#
# 1. რისი ტოლი იქნება ცვლადი `i`
# ```python
# i = 17
# i += 1
# ```
#
# 2. რისი ტოლი იქნებიან `a` და `b` პროგრამის შესრულების შემდეგ, თუ მათი საწყისი მნიშვნელობებია 4 და 7 შესაბამისად:
# ```python
# a += 1
# b += 1
# a += b
# b += a
# a += 1
# ```
#
# 3. განსაზღვრეთ ოპერატორების თანმიმდევრობა გამოსახულების გამოთვლისას:
# ```python
# a = c + b - 1 / 2 * 5
# ```
#
# 4. `python` ენაზე ჩაწერეთ მინიჭება:
# $$
# z = a + \frac{b - 5}{c + 8}
# $$
#
# 5. დაწერეთ პროგრამა, რომელიც ორ ცვლადს გაუცვლის მნიშვნელობებს.
#
# 6. როგორ განვსაზღვროთ სწრაფად რისი ტოლის `N` რიცხვის `100`-ზე გაყოფისას მიღებული ნაშთი?
#
# 7. ნებისმიერი მთელი რიცხვიდან `//` და `%` ოპერატორების გამოყენებით მივიღითო ბოლოდან მეორე ციფრი.
#
# 8. რა დაიბეჭდება?
# ```python
# a = 1
# b = 2
# c = 3
# d = 4
# e = 5
# print(f"{a:4}")
# print(f"{b:3}{b:2}")
# print(f"{c:2}{c:4}")
# print(f"{d}{d}{d}{d}{d}{d}{d}{d}")
# print(f"{4e}")
# ```
#
# 9. რა დაიბეჭდება პროგამის ფრაგმენტის შესრულებისას?
# ```python
# a = 5
# b = 3
# print(a, "=Z(", b, ")", sep='')
# print("Z(a)=", "(b)", sep='')
# print("Z(", a, ")=(", a+b, ")", sep='')
# ```
#
# 10. დაწერეთ დაბეჭდვის ფუნქცია ცვლადებისათვის `a = 5` და `b = 3` შემდეგი ფორმატით:
# ```python
# ა) 3 + 5 = ?
# ბ) Z(5) = F(3)
# გ) a = 5; b = 3
# დ) პასუხი: (5;3)
# ```
#
# 11. დაწერეთ პროგრამა, რომელიც დაბეჭდავს ჯამს, ნამრავლს და საშუალო არითმეტიკულს სამი მთელი რიცხვისთვის. რიცხვები შევიტანოთ კლავიატურიდან. მაგალითად: 3, 4 და 7 რიცხვებისთვის ეკრანზე უნდა გამონათდეს:
# ```python
# 4 + 5 + 7 = 16
# 4 * 5 * 7 = 140
# (4 + 5 + 7) / 3 = 5.3333333
# ```
#
# 12. ვთქვათ, `a = 26` და `b = 6`. გამოთვალეთ `c` ცვლადის მნიშვნელობა პროგრამის გაუშვებლად. მიღებული შედეგი შეამოწმეთ პროგრამის დახმარებით:
# ```python
# c = a % b + b
# c = a // b + a
# ```
# ```python
# b = a // b
# c = a // b
# ```
# ```python
# b = a // b + b
# c = a % b + a
# ```
# ```python
# b = a % b + 4
# c = a % b + 1
# ```
# ```python
# b = a // b
# c = a % (b + 1)
# ```
# ```python
# b = a % b
# c = a // (b + 1)
# ```
#
# 13. დაწერეთ პროგრამა, რომელიც მომთხოვს სამნიშნა ნატურალური რიცხვის შეტანას და დაბეჭდავს მის ციფრებს. მაგ.: `123`-ის შეტანისას პროგრამამ უნდა დაბეჭდის `1, 2, 3`.
#
#
# 14. კლავიატურიდან შეიტანეთ რიცხვი, რომელიც წარმოადგენს წამების რაოდენობას. პროგრამამ უნდა გამოიტანოს იგივე დრო: ფორმატით: საათი:წუთი:წამი. მაგ.:
#
#     `745`
#
#     `0:12:25`
#
#
# 15. სკოლაში გაკვეთილები იწყება `8:30`. გაკვეთილი მიმდინარეობს `45` წუთი. მათ შორის დასვენება `5` წუთია. დაწერეთ პროგრამა, რომელიც მოგთხოვთ გაკვეთილის ნომერს და გამოიტანს მისი დამთავრების დროს ფორმატით: საათი:წუთი.
#
#
# 16. კლავიატურიდან შეიტანეთ ოთხნიშნა ნატურალური რიცხვი. პროგრამამ უნდა გაუცვალოს ადგილი პირველ და მეოთხე ციფრებს და დაბეჭდოს შეცვლილი რიცხვი. მაგ.:
#
#     `1234`
#     `4231`
#
#
# 17. შევიტანოთ ოთხნიშნა ნატურალური რიცხვი. _„ამოვჭრათ“_ მეორე ციფრი და მიღებული რიცხვი დავბეჭდოთ. მაგ.:
#     `1234`
#     `134`
#
#
# 18. პროგრამამ უნდა გამოთვალოს ნაყიდი ღვეზელების ფასი (ლარი და თეთრი). შესატანი მონაცემებია 3 მთელი რიცხვი: ღვეზელის ფასი (ლარში და თეთრში), და ღვეზელის რაოდენობა. გამოსატანი -- ფასი ლარში და თეთრში. მაგ.: 3 ლარი და 25 თეთრი.
#
#
# 19. დაწერეთ პროგრამა, რომელიც შეცვლის ავტომატის მუშაობას. ავტომატი შეტანისას ითხოვს ოთხნიშნა ნატურალურ რიცხვს. შემდეგ ითვლის სამ ოპერაციას: პირველი ორი ციფრის ჯამს, შუა ციფრების ჯამს და ბოლო ორი ციფრის ჯამს. გამოტანისას კი ბეჭდავს ოპერაციების ჯამს.

# %% [markdown]
# დაწერეთ პროგრამა, რომელიც მომთხოვს სამნიშნა ნატურალური რიცხვის შეტანას და დაბეჭდავს მის ციფრებს. მაგ.: 123-ის შეტანისას პროგრამამ უნდა დაბეჭდის 1, 2, 3.

# %%
numb = 123
print(numb // 100, numb // 10 % 10, numb % 10, sep=', ')
# Out:
# 1, 2, 3

# %% [markdown]
# კლავიატურიდან შეიტანეთ რიცხვი, რომელიც წარმოადგენს წამების რაოდენობას. პროგრამამ უნდა გამოიტანოს იგივე დრო: ფორმატით: საათი:წუთი:წამი. მაგ.:

# %%
numb = 745
print(f"{numb // 3600}:{numb // 60}:{numb % 60}")
# Out:
# 0:12:25

# %% [markdown]
# სკოლაში გაკვეთილები იწყება 8:30. გაკვეთილი მიმდინარეობს 45 წუთი. მათ შორის დასვენება 5 წუთია. დაწერეთ პროგრამა, რომელიც მოგთხოვთ გაკვეთილის ნომერს და გამოიტანს მისი დამთავრების დროს ფორმატით: საათი:წუთი.

# %%
start = 8 * 3600 + 30 * 60
lesson = 45 * 60
antract = 5 * 60
n = 4
finish = start + lesson * n + antract * (n - 1)

print(f"{n} გაკვეთილის დასრულების დრო: {finish // 3600:02d}:{finish // 60 % 60:02d}")
print("{} გაკვეთილის დასრულების დრო: {:02d}:{:02d}".format(n, (finish // 3600), finish // 60 % 60))
# Out:
# 4 გაკვეთილის დასრულების დრო: 11:45
# 4 გაკვეთილის დასრულების დრო: 11:45

# %% [markdown]
# კლავიატურიდან შეიტანეთ ოთხნიშნა ნატურალური რიცხვი. პროგრამამ უნდა გაუცვალოს ადგილი პირველ და მეოთხე ციფრებს და დაბეჭდოს შეცვლილი რიცხვი. მაგ.:
#
# `1234`
# `4231`

# %%
numb = 1234
print(numb % 10, numb //100 % 10, numb // 10 % 10, numb // 1000, sep='')
# Out:
# 4231

# %% [markdown]
# პროგრამამ უნდა გამოთვალოს ნაყიდი ღვეზელების ფასი (ლარი და თეთრი). შესატანი მონაცემებია 3 მთელი რიცხვი: ღვეზელის ფასი (ლარში და თეთრში), და ღვეზელის რაოდენობა. გამოსატანი -- ფასი ლარში და თეთრში. მაგ.: 3 ლარი და 25 თეთრი.

# %%
n = int(input("ღვეზელის რაოდენობა: "))
x = int(input("ლარი: "))
y = int(input("თეთრი: "))

z = (x * 100 + y) * n

print(f"{n} ღვეზელის ფასია {z // 100} ლარი და {z % 100} თეთრი.")
# Out:
# ღვეზელის რაოდენობა: 3
# ლარი: 1
# თეთრი: 25
# 3 ღვეზელის ფასია 3 ლარი და 75 თეთრი.
