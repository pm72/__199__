# %% [markdown]
# ### რა გქვიათ თქვენ?
#
# დავწეროთ პროგრამა, რომელიც გვკითხავს სახელს და მოგვესალმება შესაბამისი ინფორმაციის შეტანის შემდეგ. მაგ.:
#
# `სახელი: პაატა`
#
# `გამარჯობა პაატა!`

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print(48)
print(14, 87, 10, "paata")

print("paata ", end='')
print(48)
# Out:
# 48
# 14 87 10 paata
# paata 48

# %%
print("სახელი: ", end='')
name = input()

print("გამარჯობა ", name, "!", sep='')
# Out:
# სახელი: paata
# გამარჯობა paata!

# %% [markdown]
# შეიძლება ასეც ჩავწეროთ:

# %%
name = input("სახელი: ")

print("გამარჯობა ", name, "!", sep='')
# Out:
# სახელი: paata
# გამარჯობა paata!

# %%
print("სახელი: ")
name = input()

print("გამარჯობა ", name, "!", sep='')
# Out:
# სახელი:
# paata
# გამარჯობა paata!

# %% [markdown]
# ### ცვლადი
#
# ცვლადი – სიდიდე, რომელსაც გააჩნია სახელი, ტიპი და მნიშვნელობა. ცვლადის მნიშვნელობა პროგრამის მსვლელობისას შეიძლება შეიცვალოს.
#
# ცვლადის სახელი უნდა შეიცავდეს ლათინურ ასოებს (დიდი და პატარა ასოები განსხვავდებიან), ციფრებს და ქვედა ტირეს. მაგ.: `number, num123, num_1` და ა.შ. `num` და `Num` სხვადასხვა ცვლადია.
#
# არ შეიძლება ცვლადის სახელი ციფრით იწყებოდეს.
#
# სასურველია ცვლადს ერქვას აზრობრივი სახელი, რათა ადვილად მივხვდეთ რა სახის ინფორმაციას ინახავს იგი. მაგ.: ცვლადი სახელით `name` მიუთითებს რომ მასში სახელი ინახება, ხოლო  ცვლადი `abc` მნშვნელობის მიხვედრა ძნელია.
#
# `Python`-ში ცვლადის შესაქმნელად საჭიროა მას მივანიჭოთ მნიშვნელობა, პროგრამირების ენაზე რომ ვთქვათ, მოვახდინოთ ცვლადის ინიციალიზება. ამით ჩვენ კომპიუტერის მეხსიერებაში (RAM) გამოიყოფა შესაბამისი ადგილი ამ ცვლადისთვის. ტიპი განისაზღვრება ავტომატურად მინიჭებისას. მოკლედ ტომ ვთქვათ, თუ გვინდა ახალი ცვლადის გამოყენება, მას უნდა მივანიჭოთ რაიმე მნიშვნელობა, შემდეგ შეგვიძლია ეს მნიშვნელობა შევცვალოთ.
#
# პროგრამირების სხვა ენებში (`C++, pascal, java...`) ეს ასე არ არის. იქ შესაძლებელია ინიციალიზაციის გარეშე გამოვაცხადოთ ცვლადი და მერე მივანიჭოთ მნიშვნელობა, ოღონდ გამოცხადებისას უნდა მივუთითოთ ტიპი და მერე ამ ტიპის შესაბამისი მნიშვნელობა მივანიჭოთ. მაგ.: თუ ცვლადი გამოცხადდა როგორც მთელი ტიპი,მას მხოლოდ მთელი ტიპის რიცხვი უნდა მივანიჭოთ და არა ათწილადის, ან სტრიქონული. წინააღმდეგ შემთხვევაში აღიძვრება შეცდომა.
#
# `python`-ში სხვაგვარადაა: ტიპები განისაზღვრება მინიჭებისას და ცვლადი იქმნება ამ მინიჭების შედეგად. შესაძლებელია სხვა ტიპის ცვლადს მივანიჭოთ სხვა ტიპის მნიშვნელობა. უკანასკნელი მინიჭების საფუძველზე ცვლადის ტიპი ავტომატურად გახდება ბოლოს მინიჭებული მნიშვნელობის ტიპის. უფრო სწორად, ცვლადის სახელი მიუთითებს მეხსიერების იმ უბანს, რომლის ტიპიც არის მნიშვნელობა.
#
# ```python
# name = "პლატონი"
# name = "სოკრატე"
# ```
#
# ცვლადის ტიპების გასაგებად გამოიყენება ჩაშენებული ფუნქცია `type()`:

# %%
lang = 'Kotlin'
print(lang, "<=====>", type(lang))

cost = 123
print(cost, "   <=====>", type(cost))

dist = 45.678
print(dist, "<=====>", type(dist))
# Out:
# Kotlin <=====> <class 'str'>
# 123    <=====> <class 'int'>
# 45.678 <=====> <class 'float'>

# %% [markdown]
# `str` – სიმბოლური ტიპი (ინგ. string – სტრიქონი)
#
# `int` – მთელი ტიპი (ინგ. integer – მთელი)
#
# `float` – ათწილადი (ნამდვილი) ტიპი (ინგ. float – მცოცავწერტილიანი)
#
# `Python` ტრანსლიატორი თავად განსაზღვრავს ტიპს მინიჭებული მნიშვნელობის მიხედვით.

# %% [markdown]
# ### რიცხვების შეკრება

# %%
print(12345 + 67890)
# Out:
# 80235

# %%
num1 = 12345
num2 = 67890

print(num1 + num2)
# Out:
# 80235

# %% [markdown]
# ამ პროგრამის ნაკლია ის, რომ რამდენჯერაც არ უნდა გავუშვათ იგი, იმავე შედეგს მოგვცემს: ცვლადები არ იცვლება და მათი ჯამიც სულ ერთი და იგივე რიცხვი იქნება. გადავაკეთოთ ისე, რომ მომხმარებელმა შეიტანოს რიცხვების მნიშვნელობა. შედეგი დამოკიდებული იქნება შეტანილ რიცხვებზე.

# %%
num1 = input()
num2 = input()

s = num1 + num2

print(s)
# Out:
# 25
# 21
# 2521

# %%
a = int('25')
print(a)

a = int(25.89)
print(a)
# Out:
# 25
# 25

# %%
num1 = int(input())      # num1 = '25'
num2 = int(input())      # num1 = '21'

s = num1 + num2

print(s)
# Out:
# 8
# 3
# 11

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1 = int(input())
num2 = int(input())

s = num1 + num2

print(num1, "+", num2, "=", s)
print(num1, "-", num2, "=", num1 - num2)
print(num1, "+", num2, "=", s, sep='')
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 5
# 8
# 5 + 8 = 13
# 5 - 8 = -3
# 5+8=13

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")

x, y, z = 9, 5, 15
print(x, y, z)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 9 5 15

# %%
names = "paata teona demetre alexandre"
print(names)
print(names.split())

name1, name2, name3, name4 = names.split()
print('name1 =', name1)
print('name2 =', name2)
print('name3 =', name3)
print('name4 =', name4)
# Out:
# paata teona demetre alexandre
# ['paata', 'teona', 'demetre', 'alexandre']
# name1 = paata
# name2 = teona
# name3 = demetre
# name4 = alexandre

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
s = input()

num1, num2 = s.split()

print(num1 + num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 5 7
# 57

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1, num2 = input().split()

print(num1 + num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 5 7
# 57

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1, num2 = int(input().split())

print(num1 + num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 5 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-3185e4799f15> in <module>()
#       1 print("შეიტანეთ ორი მთელი რიცხვი:")
# ----> 2 num1, num2 = int(input().split())
#       3
#       4 print(num1 + num2)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1, num2 = map(int, ['15', '25'])
num1, num2 = map(int, input().split())    # num1, num2 = map(int, ['45', '10'])

print(num1 + num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 45 10
# 55

# %% [markdown]
# ### მონაცემების ერთ ხაზზე შეტანა

# %% [markdown]
# აქამდე მონაცემები (`num1, num2`) შეგვყავდა ახალ-ახალი ხაზიდან (ცალ-ცალკე), ჯერ პირველი რიცხვი, შემდეგ `enter`-ის დაჭერის შემდეგ -- მეორე. შესაძლებელია მონაცემების შეტანა ერთ ხაზზე.
#
# დავუშვათ, გვინდა ორი რიცხვი შევიტანოთ ერთი ხაზიდან: ვკრებთ ჯერ პირველ რიცხვს, შემდეგ -- ინტერვალს, ვაგრძელებთ მეორე რიცხვის შეტანას და ბოლოს ვაფიქსირებთ `enter`-ით. ამ შემთხვევაში `num1` ცვლადში მოთავსდება პირველი რიცხვი, `num2`-ში კი -- მეორე. ჩავწეროთ პროგრამის ფრაგმენტი:

# %%
name = 'Paata Mamporia'
print(name.split())

f_name, l_name = name.split()
print(f_name)
print(l_name)
# Out:
# ['Paata', 'Mamporia']
# Paata
# Mamporia

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
s = input()
num1, num2 = s.split()

num1 = int(num1)
num2 = int(num2)

print("შეტანილი რიცხვები:", num1, num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 56 69
# შეტანილი რიცხვები: 56 69

# %%
word = "პაატა, თეონა, დემეტრე..."
print(word.split())
print(word.split(','))
print(word.split(', '))
# Out:
# ['პაატა,', 'თეონა,', 'დემეტრე...']
# ['პაატა', ' თეონა', ' დემეტრე...']
# ['პაატა', 'თეონა', 'დემეტრე...']

# %% [markdown]
# `input()` ფუნქციის საშუალებით `s` ცვლადში მოთავსდება ეკრანიდან აკრეფილი ორი რიცხვი და მათ შორის ინტერვალი. მიაქციეთ ყურადღება, რომ ცვლადში ინახება ტექსტი: პირველი რიცხვი, ინტერვალი (`space`) და მეორე რიცხვი. `int(s)` ჩაწერა არ შეიძლება, რადგან `s` ცლადში წერია ტექსტი და ორი რიცხვი.
#
# ამ რიცხვების განსაცალკავცებლად გამოიყენება ფუნქცია `split()`. თუ ფრჩხილებში არ ჩავწერთ არაფერს, იგულისხმება რომ გამყოფი სიმბოლო არის ან `space`, ან `enter <===> '\n'` ან ტაბულაცია `\t` (ოთხი `space`). ჩვნენ შემთხვევაში რიცხვების გამყოფი არის ინტერვალი.
#
# `num1, num2 = s.split()` ნიშნავს რომ აკრეფილი რიცხვები დაიყოფა ორ ნაწილად და ცვლადებში მოთავსდება ორივე რიცხვი შესაბამისად `num1`-ში პირველი და `num2`-ში მეორე. შემდეგ ტექსტურ რიცხვებს გარდავქმნით მთელ რიცხვებად (`num1 = int(num1) და  num2 = int(num2)`) და ვბეჭდავთ.
#
# `num1, num2 = s.split()` გამოსახულებაში გამოიყენება *„მრავალმხრივი მინიჭება“* -- ერთ გამოსახულებაში ხდება ორი ცვლადისთვის მნიშვნელობების მინიჭება.
#
# შესაძლებელია პროგრამის ფრაგმენტი უფრო კომპაქტურად ჩავწეროთ:

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1, num2 = input().split()

num1 = int(num1)
num2 = int(num2)

print("შეტანილი რიცხვები:", num1, num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 56 128
# შტანილი რიცხვები: 56 128

# %% [markdown]
# ან კიდევ უფრო მოკლედ:

# %%
print("შეიტანეთ ორი მთელი რიცხვი:")
num1, num2 = map(int, input().split())

print("შტანილი რიცხვები:", num1, num2)
# Out:
# შეიტანეთ ორი მთელი რიცხვი:
# 15 69
# შტანილი რიცხვები: 15 69

# %% [markdown]
# აქ გამოიყენება ფუნქცია `map()`, რომელიც არგუმენტად იყენებს სხვა ფუნქციას, ჩვენ შემთხვევაში `int`, მეორე არგუმენტად კი ეკრანიდან შეტანილ ინფორმაციას, რომელიც დაყოფილია ორ ნაწილად `input().split()`. ეს დაყოფილი რიცხვები, როგორც მთელი რიცხვები, მიენიჭება ცვლადებს.
#
# *„მრავალმხრივი მინიჭებისას“* უნდა გავითვალისწინოთ ის, რომ მინიჭების მარცხენა მხარეს ჩაწერილი ცვლადების რაოდენობა უნდა უმთხვეოდეს ეკრანიდან (კლავიატურიადან) აკრეფილ მონაცემთა რაოდენობას `space`-ების გამოკლებით. ვკრებთ ორი რიცხვს, ე.ი. მინიჭების მარცნივ ორი ცვლადი უნდა გვქონდეს: არც მეტი, არც ნაკლები. წინააღმდეგ შემთხვევაში აღიძვრება შეცდომა.

# %% [markdown]
# ### დავალება
#
# 1.  `Python`-ში ცვლადების რომელი სახელებია სწორი?
#
#     ```python
#     ა) 1      ბ) m11       გ) 1m       დ) vano
#     ე) brads brother   ვ) m1-45  ზ) my_name
#     ```
#
# 2.  რა როლს თამაშობს ჩანაწერი `sep=""` ფუნქცია `print()`ში:
#
#     ```python
#     print("Hello", name, "!", sep="")
#     ```
#
# 3. რით განსხვავდება ა) და ბ) პროგრამის შედეგი?
#
#     ```python
#     ა)
#     print("რა გქვიათ თქვენ?")
#     name = input()
#
#     ბ)
#     name = input("რა გქვიათ თქვენ? ")
#     ```
#
# 4.  რა დაიბეჭდება?
#
#     ```python
#     name = "მარიამი"
#     print("გამარჯობა ", name, "!")
#     print("გამარჯობა ", "name", "!")`
#
#     a = 1
#     print(a)
#     a = 5
#     print(a)
#     ```
#
# 5. რას დაბეჭდავს პროგრამა, თუ `a = 4, b = 5, c = 9`
#
#     ```python
#     print("a", "+b", "=", c)
#     ```
#
# 6. გაასწორეთ შეცდომა:
#
#     ```python
#     print("c", "-b", =, a)
#     ```
#
#     a = 4, b = 5, c = 9.
#     პროგრამამ უნდა დაბეჭდოს 9-5=4
