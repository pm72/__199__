# %%
from random import randint

print("ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით")
number = randint(1, 1000)

try:
    guess = int(input("შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

    attempt = 0
    while guess:
        if guess == number:
            print("შენ გამოიცანი.")
            print("ამისთვის დაგჭირდა", attempt, "ცდა.")
            break
        elif guess < number: print("ნაკლებია <")
        else: print("მეტია >")

        guess = int(input("\nშეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

        attempt += 1

    print("ჩაფრიქრებული იყო", number)
    print("\nდასასრული.")
except ValueError: print("მხოლოდ მთელი რიცხვი!")
# Out:
# ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 5,98
# მხოლოდ მთელი რიცხვი!

# %%
from random import randint

print("ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით")
number = randint(1, 1000)
print(number)

quite = False
while not quite:
    try:
        guess = int(input("შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

        point = 50
        attempt = 0
        while guess:
            attempt += 1
            
            if guess == number:
                print("შენ გამოიცანი.")
                print("ამისთვის დაგჭირდა", attempt, "ცდა.")
                quite = True
                break
            elif guess < number: print("ნაკლებია <")
            else: print("მეტია >")

            point -= attempt
                
            if point < 0:
                quite = True
                point = 0
                print("\nცდა", attempt)
                break
            
            guess = int(input("\nშეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

        print("ჩაფრიქრებული იყო", number)
        
        if not guess: break
            
        print("ქულა:", point)
        
        
    except ValueError: print("მხოლოდ მთელი რიცხვი!")

print("\nდასასრული.")
# Out:
# ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით
# 690
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 500
# ნაკლებია <
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 750
# მეტია >
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 600
# ნაკლებია <
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 650
# ნაკლებია <
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 700
# მეტია >
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 680
# ნაკლებია <
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 690
# შენ გამოიცანი.
# ამისთვის დაგჭირდა 7 ცდა.
# ჩაფრიქრებული იყო 690
# ქულა: 29
#
# დასასრული.

# %%
from random import randint

print("ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით")
number = randint(1, 1000)
print(number)

point = 50
attempt = 0

quite = False
while not quite:
    try:
        guess = int(input("შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

        while guess:
            attempt += 1
            
            if guess == number:
                print("\nშენ გამოიცანი.")
                print("ამისთვის დაგჭირდა", attempt, "ცდა.")
                quite = True
                break
            elif guess < number: print("ნაკლებია <")
            else: print("მეტია >")

            point -= attempt
                
            if point < 0:
                quite = True
                point = 0
                print("\nცდა", attempt)
                break
            
            guess = int(input("\nშეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: "))

        print("ჩაფრიქრებული იყო", number)
        
        if not guess: break
            
        print("ქულა:", point)
        
        
    except ValueError: print("მხოლოდ მთელი რიცხვი!\n")

print("\nდასასრული.")
# Out:
# ჩავიფიქრე რიცხვი 1-დან 1000-ის ჩათვლით
# 668
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 500
# ნაკლებია <
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 568.2
# მხოლოდ მთელი რიცხვი!
#
# შეიტანეთ მთელი დადებითი რიცხვი [0 – დამთავრება]: 668
#
# შენ გამოიცანი.
# ამისთვის დაგჭირდა 1 ცდა.
# ჩაფრიქრებული იყო 668
# ქულა: 50
#
# დასასრული.
